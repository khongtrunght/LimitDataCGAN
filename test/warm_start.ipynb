# %%
import torch

# %%
# %cd ..
# Out:
# c:\Users\khong\PycharmProjects\pythonProject

# %%
state_dict_D = torch.load('pretrains/netD_epoch_199.pth')

# %%
print(state_dict_D.keys())
# Out:
# odict_keys(['main.0.weight', 'main.2.weight', 'main.3.weight', 'main.3.bias', 'main.3.running_mean', 'main.3.running_var', 'main.3.num_batches_tracked', 'main.5.weight', 'main.6.weight', 'main.6.bias', 'main.6.running_mean', 'main.6.running_var', 'main.6.num_batches_tracked', 'main.8.weight', 'main.9.weight', 'main.9.bias', 'main.9.running_mean', 'main.9.running_var', 'main.9.num_batches_tracked', 'main.11.weight'])

# %%
print(state_dict_D['main.11.weight'].shape)
# Out:
# torch.Size([1, 512, 2, 2])

# %%
print(state_dict_D['main.9.bias'].shape)
# Out:
# torch.Size([512])

# %%
print(state_dict_D['main.9.running_mean'].shape)

# %%
our_model = torch.load('model.pth')

# %%
our_model.keys()
# Out:
# odict_keys(['generator.net.0.0.weight', 'generator.net.0.1.weight', 'generator.net.0.1.bias', 'generator.net.0.1.running_mean', 'generator.net.0.1.running_var', 'generator.net.0.1.num_batches_tracked', 'generator.net.1.0.weight', 'generator.net.1.1.weight', 'generator.net.1.1.bias', 'generator.net.1.1.running_mean', 'generator.net.1.1.running_var', 'generator.net.1.1.num_batches_tracked', 'generator.net.2.0.weight', 'generator.net.2.1.weight', 'generator.net.2.1.bias', 'generator.net.2.1.running_mean', 'generator.net.2.1.running_var', 'generator.net.2.1.num_batches_tracked', 'generator.net.3.0.weight', 'generator.net.3.1.weight', 'generator.net.3.1.bias', 'generator.net.3.1.running_mean', 'generator.net.3.1.running_var', 'generator.net.3.1.num_batches_tracked', 'generator.net.4.weight', 'generator.embed.weight', 'discriminator.net.0.weight', 'discriminator.net.0.bias', 'discriminator.net.2.0.weight', 'discriminator.net.2.1.weight', 'discriminator.net.2.1.bias', 'discriminator.net.3.0
# ...

# %%
print(our_model['generator.net.0.0.weight'].shape)
# Out:
# torch.Size([150, 256, 4, 4])

# %%
state_dict_G = torch.load('pretrains/netG_epoch_199.pth')

# %%
print(state_dict_G.keys())
# Out:
# odict_keys(['main.0.weight', 'main.1.weight', 'main.1.bias', 'main.1.running_mean', 'main.1.running_var', 'main.1.num_batches_tracked', 'main.3.weight', 'main.4.weight', 'main.4.bias', 'main.4.running_mean', 'main.4.running_var', 'main.4.num_batches_tracked', 'main.6.weight', 'main.7.weight', 'main.7.bias', 'main.7.running_mean', 'main.7.running_var', 'main.7.num_batches_tracked', 'main.9.weight', 'main.10.weight', 'main.10.bias', 'main.10.running_mean', 'main.10.running_var', 'main.10.num_batches_tracked', 'main.12.weight'])

# %%
print(state_dict_G['main.9.weight'].shape)
# Out:
# torch.Size([128, 64, 4, 4])

# %%
print(our_model['discriminator.net.5.weight'].shape)
# Out:
# torch.Size([1, 256, 4, 4])

# %%
print(state_dict_D['main.8.weight'].shape)
# Out:
# torch.Size([512, 256, 4, 4])

# %%
print(state_dict_D['main.5.weight'].shape)
# Out:
# torch.Size([256, 128, 4, 4])

# %%
print(state_dict_D['main.2.weight'].shape)
# Out:
# torch.Size([128, 64, 4, 4])

# %%
print(state_dict_D['main.0.weight'].shape)
# Out:
# torch.Size([64, 3, 4, 4])

# %%
netD29 = torch.load('pretrains/netD_29.pth')

# %%
print(netD29['main.8.weight'].shape)
# Out:
# torch.Size([512, 256, 4, 4])
